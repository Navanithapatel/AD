# %% [markdown]
# <a href="https://colab.research.google.com/github/Navanithapatel/AD/blob/main/pythonday19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np

# %%
cars=pd.read_csv(r"/content/Cars.csv")
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.tail()
# Out:
#      HP        MPG  VOL          SP         WT
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615

# %%
cars.shape
# Out:
# (81, 5)

# %%
cars.sample
# Out:
# <bound method NDFrame.sample of      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]>

# %%
cars[70:76]
# Out:
#      HP        MPG  VOL          SP         WT
# 70  280  19.678507   50  164.598513  15.823060
# 71  162  23.203569  135  133.415985  44.013139
# 72  162  23.203569  132  133.140074  43.353123
# 73  140  19.086341  160  124.715241  52.997752
# 74  140  19.086341  129  121.864163  42.618698
# 75  175  18.762837  129  132.864163  42.778219

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.describe
# Out:
# <bound method NDFrame.describe of      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]>

# %%
cars
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
cars.isnull()
# Out:
#        HP    MPG    VOL     SP     WT
# 0   False  False  False  False  False
# 1   False  False  False  False  False
# 2   False  False  False  False  False
# 3   False  False  False  False  False
# 4   False  False  False  False  False
# ..    ...    ...    ...    ...    ...
# 76  False  False  False  False  False
# 77  False  False  False  False  False
# 78  False  False  False  False  False
# 79  False  False  False  False  False
# 80  False  False  False  False  False
#
# [81 rows x 5 columns]

# %%
cars.isna().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(cars['HP'])
# Out:
# <Axes: xlabel='HP', ylabel='Density'>

# %%
sns.distplot(cars['SP'])
# Out:
# <Axes: xlabel='SP', ylabel='Density'>

# %%
sns.distplot(cars['VOL'])
# Out:
# <Axes: xlabel='VOL', ylabel='Density'>

# %%
sns.distplot(cars['WT'])
# Out:
# <Axes: xlabel='WT', ylabel='Density'>

# %%
sns.distplot(cars['MPG'])
# Out:
# <Axes: xlabel='MPG', ylabel='Density'>

# %%
sns.boxplot(cars['HP'])
# Out:
# <Axes: ylabel='HP'>

# %%
sns.boxplot(cars['SP'])
# Out:
# <Axes: ylabel='SP'>

# %%
sns.boxplot(cars['VOL'])
# Out:
# <Axes: ylabel='VOL'>

# %%
sns.boxplot(cars['MPG'])
# Out:
# <Axes: ylabel='MPG'>

# %%
from seaborn import scatterplot

# %%
sns.scatterplot(cars['HP'])
# Out:
# <Axes: ylabel='HP'>

# %%
scatterplot
scatterplot(x=cars['HP'],y=cars['MPG'])
# Out:
# <Axes: xlabel='HP', ylabel='MPG'>

# %%
cars.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
sns.heatmap(cars.corr(),cmap='Greens',annot=True)
plt.show()
