# %% [markdown]
# <a href="https://colab.research.google.com/github/Navanithapatel/AD/blob/main/pythonday11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
k=[4,2.56789,9,87.9999,40,'hyderabad']
k
# Out:
# [4, 2.56789, 9, 87.9999, 40, 'hyderabad']

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
k=[4,2,9,87.9999,40]
k
# Out:
# [4, 2, 9, 87.9999, 40]

# %%
pd.Series(k)
# Out:
# 0     4.0000
# 1     2.0000
# 2     9.0000
# 3    87.9999
# 4    40.0000
# dtype: float64

# %%
a=np.random.randint(20,50,(5,4))
a
# Out:
# array([[32, 41, 38, 38],
#        [40, 37, 41, 45],
#        [47, 43, 38, 43],
#        [31, 22, 39, 31],
#        [23, 43, 29, 42]])

# %%
a.ndim
# Out:
# 1

# %%
a=np.random.randint(20,50,(5,4))
a
# Out:
# array([[29, 27, 21, 21],
#        [28, 43, 20, 32],
#        [21, 36, 47, 47],
#        [23, 36, 43, 35],
#        [27, 20, 48, 29]])

# %%
pd.Series(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-4c5cf694b436> in <cell line: 0>()
# ----> 1 pd.Series(a)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     582                 data = data.copy()
#     583         else:
# --> 584             data = sanitize_array(data, index, dtype, copy)
#     585
#     586             manager = _get_option("mode.data_manager", silent=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, allow_2d)
#     657                 subarr = maybe_infer_to_datetimelike(subarr)
#     658
# --> 659     subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     660
#     661     if isinstance(subarr, np.ndarray):
#
# ...

# %%
a=np.random.randint(20,50,15)
a
# Out:
# array([21, 39, 43, 23, 48, 26, 28, 37, 27, 21, 32, 21, 49, 28, 30])

# %%
pd.Series(a)
# Out:
# 0     21
# 1     39
# 2     43
# 3     23
# 4     48
# 5     26
# 6     28
# 7     37
# 8     27
# 9     21
# 10    32
# 11    21
# 12    49
# 13    28
# 14    30
# dtype: int64

# %%
a[5]
# Out:
# 26

# %%
np.random.seed(34)#seed is used to get same numbers / matrices
b=np.random.randint(100,200,(6,5))
b
# Out:
# array([[133, 185, 168, 135, 169],
#        [111, 178, 129, 118, 129],
#        [189, 129, 120, 196, 162],
#        [105, 120, 151, 119, 185],
#        [121, 163, 172, 142, 184],
#        [172, 177, 136, 102, 137]])

# %%
b.ndim
# Out:
# 2

# %%
b
# Out:
# array([[133, 185, 168, 135, 169],
#        [111, 178, 129, 118, 129],
#        [189, 129, 120, 196, 162],
#        [105, 120, 151, 119, 185],
#        [121, 163, 172, 142, 184],
#        [172, 177, 136, 102, 137]])

# %%
df=pd.DataFrame(b)
df
# Out:
#      0    1    2    3    4
# 0  133  185  168  135  169
# 1  111  178  129  118  129
# 2  189  129  120  196  162
# 3  105  120  151  119  185
# 4  121  163  172  142  184
# 5  172  177  136  102  137

# %%
df=pd.DataFrame(b,columns=['Roll','Name','Age','Id','Country'])
df
# Out:
#    Roll  Name  Age   Id  Country
# 0   133   185  168  135      169
# 1   111   178  129  118      129
# 2   189   129  120  196      162
# 3   105   120  151  119      185
# 4   121   163  172  142      184
# 5   172   177  136  102      137

# %%
df=pd.DataFrame(b,columns=['Roll','Name','Age','Id','Country'],index=[11,12,13,14,15,16])
df
# Out:
#     Roll  Name  Age   Id  Country
# 11   133   185  168  135      169
# 12   111   178  129  118      129
# 13   189   129  120  196      162
# 14   105   120  151  119      185
# 15   121   163  172  142      184
# 16   172   177  136  102      137

# %%
df.iloc[0,0:3]
# Out:
# Roll    133
# Name    185
# Age     168
# Name: 11, dtype: int64

# %%
df.iloc[0,[0,1,2]]
# Out:
# Roll    133
# Name    185
# Age     168
# Name: 11, dtype: int64

# %%
df.iloc[[0,5]]
# Out:
#     Roll  Name  Age   Id  Country
# 11   133   185  168  135      169
# 16   172   177  136  102      137

# %%
df.iloc[1,3,4]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-50-03cef023bbe3> in <cell line: 0>()
# ----> 1 df.iloc[1,3,4]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1688
#    1689     def _getitem_tuple(self, tup: tuple):
# -> 1690         tup = self._validate_tuple_indexer(tup)
#    1691         with suppress(IndexingError):
#    1692             return self._getitem_lowerdim(tup)
#
# ...

# %%
df.loc[[11,12,13]]
# Out:
#     Roll  Name  Age   Id  Country
# 11   133   185  168  135      169
# 12   111   178  129  118      129
# 13   189   129  120  196      162

# %%
df['Age']
# Out:
# 11    168
# 12    129
# 13    120
# 14    151
# 15    172
# 16    136
# Name: Age, dtype: int64

# %%
df[['Age','Country']]
# Out:
#     Age  Country
# 11  168      169
# 12  129      129
# 13  120      162
# 14  151      185
# 15  172      184
# 16  136      137

# %%
df.loc[[11,12,13],['Name','Age','Country']]
# Out:
#     Name  Age  Country
# 11   185  168      169
# 12   178  129      129
# 13   129  120      162

# %%
#sns.load_dataset('')
sns.get_dataset_names
# Out:
# <function seaborn.utils.get_dataset_names()>

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.shape
# Out:
# (244, 7)

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.shape
# Out:
# (244, 7)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (244, 7)
