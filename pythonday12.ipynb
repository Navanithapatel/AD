# %% [markdown]
# <a href="https://colab.research.google.com/github/Navanithapatel/AD/blob/main/pythonday12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=sns.load_dataset('taxis')
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.sample(6)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 6123 2019-03-22 18:46:14 2019-03-22 19:01:30           1      2.02  11.0
# 5673 2019-03-12 00:27:58 2019-03-12 00:33:31           1      1.38   6.5
# 4628 2019-03-30 01:22:34 2019-03-30 01:35:19           2      5.44  17.0
# 3138 2019-03-21 06:11:24 2019-03-21 06:25:22           1      2.35  11.0
# 3960 2019-03-27 11:44:25 2019-03-27 11:52:10           1      0.72   6.5
# 2487 2019-03-07 17:32:25 2019-03-07 17:41:58           4      0.73   7.5
#
#        tip  tolls  total   color      payment                    pickup_zone  \
# 6123  0.00    0.0  12.80   green         cash                Jackson Heights
# 5673  0.00    0.0   7.80   green         cash           Central Harlem North
# 4628  2.00    0.0  22.80  yellow  credit card  Sutton Place/Turtle Bay North
# 3138  3.58    0.0  17.88  yellow  credit card      Times Sq/Theatre District
# ...

# %%
df.sample(3)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 3608 2019-03-03 04:17:10 2019-03-03 04:37:33           1      5.27  19.5
# 2586 2019-03-08 09:14:58 2019-03-08 10:13:40           2     10.04  42.5
# 1462 2019-03-13 14:55:14 2019-03-13 15:08:27           1      2.00  11.0
#
#         tip  tolls  total   color      payment                   pickup_zone  \
# 3608   4.66   0.00  27.96  yellow  credit card  Penn Station/Madison Sq West
# 2586  10.31   5.76  61.87  yellow  credit card             LaGuardia Airport
# 1462   0.00   0.00  14.30  yellow  credit card              Manhattan Valley
#
#                dropoff_zone pickup_borough dropoff_borough
# 3608         Central Harlem      Manhattan       Manhattan
# 2586          Midtown North         Queens       Manhattan
# 1462  Upper East Side North      Manhattan       Manhattan

# %%
df.head(5)
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
df.tail(3)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total  color      payment          pickup_zone  \
# 6430  0.00    0.0  17.30  green         cash  Crown Heights North
# 6431  0.00    0.0   6.80  green  credit card        East New York
# 6432  3.36    0.0  20.16  green  credit card          Boerum Hill
#
#                       dropoff_zone pickup_borough dropoff_borough
# 6430                Bushwick North       Brooklyn        Brooklyn
# 6431  East Flatbush/Remsen Village       Brooklyn        Brooklyn
# 6432               Windsor Terrace       Brooklyn        Brooklyn

# %%
df['color'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6428    False
# 6429    False
# 6430    False
# 6431    False
# 6432    False
# Name: color, Length: 6433, dtype: bool

# %%
df['color']
# Out:
# 0       yellow
# 1       yellow
# 2       yellow
# 3       yellow
# 4       yellow
#          ...
# 6428     green
# 6429     green
# 6430     green
# 6431     green
# 6432     green
# Name: color, Length: 6433, dtype: object

# %%
df['color'].isnull().sum()
# Out:
# 0

# %%
df['payment'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6428    False
# 6429    False
# 6430    False
# 6431    False
# 6432    False
# Name: payment, Length: 6433, dtype: bool

# %%
df.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
df['payment'].isnull().sum()
# Out:
# 44

# %%
(44/6433)*100
# Out:
# 0.6839732628633608

# %%
df.shape[0]
# Out:
# 6433

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %%
missing data handling
1)  Imputation (fill in the blanks)
     1) statical measures
     2 parameter


2) delete data
     rows
     columns
# Out:
#   File "<ipython-input-20-2808a4901d31>", line 1
#     missing data handling
#             ^
# SyntaxError: invalid syntax

# %%
df.drop('pickup_zone',axis=1)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
df.drop(['pickup','color','payment','total'],axis=1)
# Out:
#                  dropoff  passengers  distance  fare   tip  tolls  \
# 0    2019-03-23 20:27:24           1      1.60   7.0  2.15    0.0
# 1    2019-03-04 16:19:00           1      0.79   5.0  0.00    0.0
# 2    2019-03-27 18:00:25           1      1.37   7.5  2.36    0.0
# 3    2019-03-10 01:49:51           1      7.70  27.0  6.15    0.0
# 4    2019-03-30 13:37:14           3      2.16   9.0  1.10    0.0
# ...                  ...         ...       ...   ...   ...    ...
# 6428 2019-03-31 09:55:27           1      0.75   4.5  1.06    0.0
# 6429 2019-03-31 18:34:23           1     18.74  58.0  0.00    0.0
# 6430 2019-03-23 23:14:25           1      4.14  16.0  0.00    0.0
# 6431 2019-03-04 10:14:29           1      1.12   6.0  0.00    0.0
# 6432 2019-03-13 19:48:02           1      3.85  15.0  3.36    0.0
#
#                 pickup_zone                      dropoff_zone pickup_borough  \
# 0           Lenox Hill West               UN/Turtle Bay South      Manhattan
# ...

# %%
df.drop(['pickup','color','payment','total'],axis=1,inplace=True)

# %%
df
# Out:
#                  dropoff  passengers  distance  fare   tip  tolls  \
# 0    2019-03-23 20:27:24           1      1.60   7.0  2.15    0.0
# 1    2019-03-04 16:19:00           1      0.79   5.0  0.00    0.0
# 2    2019-03-27 18:00:25           1      1.37   7.5  2.36    0.0
# 3    2019-03-10 01:49:51           1      7.70  27.0  6.15    0.0
# 4    2019-03-30 13:37:14           3      2.16   9.0  1.10    0.0
# ...                  ...         ...       ...   ...   ...    ...
# 6428 2019-03-31 09:55:27           1      0.75   4.5  1.06    0.0
# 6429 2019-03-31 18:34:23           1     18.74  58.0  0.00    0.0
# 6430 2019-03-23 23:14:25           1      4.14  16.0  0.00    0.0
# 6431 2019-03-04 10:14:29           1      1.12   6.0  0.00    0.0
# 6432 2019-03-13 19:48:02           1      3.85  15.0  3.36    0.0
#
#                 pickup_zone                      dropoff_zone pickup_borough  \
# 0           Lenox Hill West               UN/Turtle Bay South      Manhattan
# ...

# %%
df.drop([2,3,4,5,6430],axis=0,inplace=True)

# %%
df
# Out:
#                  dropoff  passengers  distance  fare   tip  tolls  \
# 0    2019-03-23 20:27:24           1      1.60   7.0  2.15    0.0
# 1    2019-03-04 16:19:00           1      0.79   5.0  0.00    0.0
# 6    2019-03-26 21:17:29           1      3.65  13.0  2.00    0.0
# 7    2019-03-22 12:58:17           0      1.40   8.5  0.00    0.0
# 8    2019-03-23 12:06:14           1      3.63  15.0  1.00    0.0
# ...                  ...         ...       ...   ...   ...    ...
# 6427 2019-03-23 18:49:12           1      7.07  20.0  0.00    0.0
# 6428 2019-03-31 09:55:27           1      0.75   4.5  1.06    0.0
# 6429 2019-03-31 18:34:23           1     18.74  58.0  0.00    0.0
# 6431 2019-03-04 10:14:29           1      1.12   6.0  0.00    0.0
# 6432 2019-03-13 19:48:02           1      3.85  15.0  3.36    0.0
#
#                 pickup_zone                      dropoff_zone pickup_borough  \
# 0           Lenox Hill West               UN/Turtle Bay South      Manhattan
# ...

# %%
a=np.random.randint(10,50,15)

# %%
a[a<20]
# Out:
# array([19, 19, 19])

# %%
a[a>30]
# Out:
# array([45, 38, 43, 31])

# %%
a
# Out:
# array([45, 21, 38, 29, 27, 26, 25, 43, 31, 21, 19, 19, 19, 28, 29])

# %%
a[6]
# Out:
# 25

# %%
a[0:7]
# Out:
# array([45, 21, 38, 29, 27, 26, 25])

# %%
df.iloc[5605]
# Out:
# dropoff             2019-03-29 10:56:46
# passengers                            1
# distance                           2.89
# fare                               11.5
# tip                                 0.0
# tolls                               0.0
# pickup_zone                  Co-Op City
# dropoff_zone       Van Nest/Morris Park
# pickup_borough                    Bronx
# dropoff_borough                   Bronx
# Name: 5609, dtype: object

# %%
df.iloc[2]
# Out:
# dropoff                2019-03-26 21:17:29
# passengers                               1
# distance                              3.65
# fare                                  13.0
# tip                                    2.0
# tolls                                  0.0
# pickup_zone              Battery Park City
# dropoff_zone       Two Bridges/Seward Park
# pickup_borough                   Manhattan
# dropoff_borough                  Manhattan
# Name: 6, dtype: object

# %%
df=sns.load_dataset('taxis')

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df[df['color']=='yellow']
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 5446 2019-03-11 21:19:42 2019-03-11 21:29:23           1      2.09   9.5
# 5447 2019-03-20 18:09:46 2019-03-20 18:16:52           1      1.52   7.5
# 5448 2019-03-09 11:08:09 2019-03-09 11:18:03           1      2.05   9.5
# 5449 2019-03-22 18:12:50 2019-03-22 18:22:05           1      1.07   7.5
# 5450 2019-03-07 18:02:33 2019-03-07 18:13:32           1      1.80   9.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df['payment']=='cash'
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 6428    False
# 6429    False
# 6430     True
# 6431    False
# 6432    False
# Name: payment, Length: 6433, dtype: bool

# %%
conditional=df['payment']=='cash'
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df[(df['payment']=='cash') & (df['total']>15)]
# Out:
#                   pickup             dropoff  passengers  distance  fare  tip  \
# 10   2019-03-16 10:02:25 2019-03-16 10:22:29           1      3.90  17.0  0.0
# 15   2019-03-16 17:53:34 2019-03-16 18:13:57           3      2.09  13.5  0.0
# 16   2019-03-15 12:36:05 2019-03-15 12:54:28           1      2.12  13.0  0.0
# 26   2019-03-03 02:45:36 2019-03-03 03:02:14           1      3.35  13.5  0.0
# 29   2019-03-06 08:09:03 2019-03-06 08:27:11           1      0.92  12.0  0.0
# ...                  ...                 ...         ...       ...   ...  ...
# 6407 2019-03-07 16:35:42 2019-03-07 16:50:03           1      2.68  12.0  0.0
# 6408 2019-03-04 07:27:58 2019-03-04 07:49:25           1      6.48  22.0  0.0
# 6422 2019-03-22 20:17:35 2019-03-22 20:36:07           1      4.02  16.0  0.0
# 6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.0  0.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0  0.0
#
# ...
